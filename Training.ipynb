# %%
# !git clone https://github.com/mwritescode/smart-contracts-vulnerabilities.git
# Out:
# Cloning into 'smart-contracts-vulnerabilities'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 211 (delta 76), reused 167 (delta 48), pack-reused 0
# Receiving objects: 100% (211/211), 990.62 KiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# !pip install -r smart-contracts-vulnerabilities/requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 5)) (4.66.1)
# Collecting torchinfo (from -r smart-contracts-vulnerabilities/requirements.txt (line 6))
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from -r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2.14.1)
# Collecting hexbytes (from -r smart-contracts-vulnerabilities/requirements.txt (line 9))
#   Downloading hexbytes-1.0.0-py3-none-any.whl (5.9 kB)
# Collecting datasets[vision] (from -r smart-contracts-vulnerabilities/requirements.txt (line 10))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 11.8 MB/s eta 0:00:00
# Collecting yacs (from -r smart-contracts-vulnerabilities/requirements.txt (line 11))
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r smart-contracts-vulnerabilities/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r smart-contracts-vulnerabilities/requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r smart-contracts-vulnerabilities/requirements.txt (line 7)) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r smart-contracts-vulnerabilities/requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r smart-contracts-vulnerabilities/requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (9.0.0)
# Collecting pyarrow-hotfix (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (3.4.1)
# Collecting multiprocess (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets[vision]->-r smart-contracts-vulnerabilities/requirements.txt (line 10)) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r smart-contracts-vulnerabilities/requirements.txt (line 8)) (3.2.2)
# Installing collected packages: yacs, torchinfo, pyarrow-hotfix, hexbytes, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 hexbytes-1.0.0 multiprocess-0.70.15 pyarrow-hotfix-0.6 torchinfo-1.8.0 yacs-0.1.8

# %%
# %cd smart-contracts-vulnerabilities/
# Out:
# /content/smart-contracts-vulnerabilities

# %%
# !python main.py src/config/experiments/default.yaml
# Out:
# 2023-11-28 11:26:54.505734: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 11:26:54.505784: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 11:26:54.505826: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 11:26:56.245169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2096: FutureWarning: 'ignore_verifications' was deprecated in favor of 'verification_mode' in version 2.9.1 and will be removed in 3.0.0.
# You can remove this warning by passing 'verification_mode=no_checks' instead.
#   warnings.warn(
# Downloading builder script: 100% 8.00k/8.00k [00:00<00:00, 33.4MB/s]
# Downloading metadata: 100% 19.9k/19.9k [00:00<00:00, 55.3MB/s]
# Downloading readme: 100% 7.12k/7.12k [00:00<00:00, 24.5MB/s]
# Downloading data files:   0% 0/4 [00:00<?, ?it/s]
# Downloading data:   0% 0.00/203M [00:00<?, ?B/s]
# Downloading data:   3% 5.87M/203M [00:00<00:03, 58.7MB/s]
# Downloading data:   8% 15.9M/203M [00:00<00:02, 83.1MB/s]
# Downloading data:  12% 24.9M/203M [00:00<00:02, 86.3MB/s]
# Downloading data:  17% 34.3M/203M [00:00<00:01, 89.5MB/s]
# Downloading data:  22% 44.2M/203M [00:00<00:01, 92.9MB/s]
# Downloading data:  27% 53.8M/203M [00:00<00:01, 93.8MB/s]
# Downloading data:  31% 63.2M/203M [00:00<00:01, 90.3MB/s]
# Downloading data:  36% 72.5M/203M [00:00<00:01, 91.1MB/s]
# Downloading data:  40% 81.6M/203M [00:00<00:01, 91.0MB/s]
# Downloading data:  45% 91.4M/203M [00:01<00:01, 93.0MB/s]
# Downloading data:  50% 101M/203M [00:01<00:01, 91.3MB/s]
# Downloading data:  54% 110M/203M [00:01<00:01, 89.7MB/s]
# Downloading data:  59% 119M/203M [00:01<00:00, 91.2MB/s]
# Downloading data:  63% 128M/203M [00:01<00:00, 90.0MB/s]
# Downloading data:  68% 137M/203M [00:01<00:00, 87.0MB/s]
# Downloading data:  72% 146M/203M [00:01<00:00, 88.1MB/s]
# Downloading data:  77% 156M/203M [00:01<00:00, 91.3MB/s]
# Downloading data:  82% 166M/203M [00:01<00:00, 87.7MB/s]
# Downloading data:  86% 175M/203M [00:01<00:00, 90.6MB/s]
# Downloading data:  91% 184M/203M [00:02<00:00, 90.6MB/s]
# Downloading data: 100% 203M/203M [00:02<00:00, 90.4MB/s]
#
# Downloading data:   0% 0.00/197M [00:00<?, ?B/s]
# Downloading data:   3% 6.81M/197M [00:00<00:02, 68.1MB/s]
# Downloading data:   8% 16.5M/197M [00:00<00:02, 85.2MB/s]
# Downloading data:  13% 25.0M/197M [00:00<00:02, 67.4MB/s]
# Downloading data:  17% 33.8M/197M [00:00<00:02, 74.2MB/s]
# Downloading data:  22% 42.6M/197M [00:00<00:01, 78.8MB/s]
# Downloading data:  26% 51.6M/197M [00:00<00:01, 82.5MB/s]
# Downloading data:  31% 61.1M/197M [00:00<00:01, 86.2MB/s]
# Downloading data:  36% 69.9M/197M [00:00<00:01, 86.7MB/s]
# Downloading data:  40% 78.6M/197M [00:00<00:01, 85.5MB/s]
# Downloading data:  44% 87.3M/197M [00:01<00:01, 72.6MB/s]
# Downloading data:  48% 94.9M/197M [00:01<00:01, 67.8MB/s]
# Downloading data:  52% 102M/197M [00:01<00:01, 62.4MB/s]
# Downloading data:  55% 108M/197M [00:01<00:01, 59.6MB/s]
# Downloading data:  58% 115M/197M [00:01<00:01, 58.5MB/s]
# Downloading data:  61% 120M/197M [00:01<00:01, 56.5MB/s]
# Downloading data:  64% 126M/197M [00:01<00:01, 55.2MB/s]
# Downloading data:  67% 132M/197M [00:01<00:01, 53.0MB/s]
# Downloading data:  70% 137M/197M [00:02<00:01, 52.4MB/s]
# Downloading data:  72% 142M/197M [00:02<00:01, 51.8MB/s]
# Downloading data:  75% 148M/197M [00:02<00:00, 50.6MB/s]
# Downloading data:  78% 153M/197M [00:02<00:00, 50.1MB/s]
# Downloading data:  80% 158M/197M [00:02<00:00, 49.9MB/s]
# Downloading data:  83% 163M/197M [00:02<00:00, 49.7MB/s]
# Downloading data:  85% 168M/197M [00:02<00:00, 49.5MB/s]
# Downloading data:  88% 173M/197M [00:02<00:00, 50.3MB/s]
# Downloading data:  90% 178M/197M [00:02<00:00, 50.8MB/s]
# Downloading data:  93% 183M/197M [00:02<00:00, 51.7MB/s]
# Downloading data:  96% 189M/197M [00:03<00:00, 53.3MB/s]
# Downloading data: 100% 197M/197M [00:03<00:00, 60.9MB/s]
#
# Downloading data:   0% 0.00/193M [00:00<?, ?B/s]
# Downloading data:   2% 3.95M/193M [00:00<00:04, 39.5MB/s]
# Downloading data:   5% 9.85M/193M [00:00<00:03, 51.0MB/s]
# Downloading data:   8% 15.4M/193M [00:00<00:03, 52.9MB/s]
# Downloading data:  11% 20.8M/193M [00:00<00:03, 53.3MB/s]
# Downloading data:  14% 26.1M/193M [00:00<00:03, 53.5MB/s]
# Downloading data:  16% 31.5M/193M [00:00<00:03, 50.1MB/s]
# Downloading data:  19% 37.4M/193M [00:00<00:02, 52.7MB/s]
# Downloading data:  23% 43.4M/193M [00:00<00:02, 55.1MB/s]
# Downloading data:  27% 51.8M/193M [00:00<00:02, 63.9MB/s]
# Downloading data:  32% 61.1M/193M [00:01<00:01, 72.8MB/s]
# Downloading data:  35% 68.4M/193M [00:01<00:01, 69.5MB/s]
# Downloading data:  39% 75.7M/193M [00:01<00:01, 70.4MB/s]
# Downloading data:  44% 85.3M/193M [00:01<00:01, 78.0MB/s]
# Downloading data:  49% 94.4M/193M [00:01<00:01, 81.9MB/s]
# Downloading data:  53% 103M/193M [00:01<00:01, 80.5MB/s]
# Downloading data:  58% 111M/193M [00:01<00:00, 82.1MB/s]
# Downloading data:  62% 120M/193M [00:01<00:00, 83.7MB/s]
# Downloading data:  67% 128M/193M [00:01<00:00, 81.9MB/s]
# Downloading data:  71% 137M/193M [00:01<00:00, 83.4MB/s]
# Downloading data:  76% 146M/193M [00:02<00:00, 85.7MB/s]
# Downloading data:  80% 155M/193M [00:02<00:00, 86.4MB/s]
# Downloading data:  85% 164M/193M [00:02<00:00, 86.3MB/s]
# Downloading data:  89% 172M/193M [00:02<00:00, 86.8MB/s]
# Downloading data:  94% 181M/193M [00:02<00:00, 87.3MB/s]
# Downloading data: 100% 193M/193M [00:02<00:00, 74.7MB/s]
#
# Downloading data:   0% 0.00/224M [00:00<?, ?B/s]
# Downloading data:   3% 6.31M/224M [00:00<00:03, 63.1MB/s]
# Downloading data:   7% 15.9M/224M [00:00<00:02, 82.4MB/s]
# Downloading data:  11% 24.8M/224M [00:00<00:02, 85.2MB/s]
# Downloading data:  15% 33.3M/224M [00:00<00:02, 83.8MB/s]
# Downloading data:  19% 42.3M/224M [00:00<00:02, 86.2MB/s]
# Downloading data:  23% 51.2M/224M [00:00<00:01, 87.0MB/s]
# Downloading data:  27% 60.0M/224M [00:00<00:01, 87.5MB/s]
# Downloading data:  31% 68.8M/224M [00:00<00:01, 84.3MB/s]
# Downloading data:  34% 77.2M/224M [00:00<00:01, 76.8MB/s]
# Downloading data:  38% 85.8M/224M [00:01<00:01, 79.4MB/s]
# Downloading data:  42% 94.5M/224M [00:01<00:01, 81.6MB/s]
# Downloading data:  46% 103M/224M [00:01<00:01, 82.1MB/s]
# Downloading data:  50% 112M/224M [00:01<00:01, 83.6MB/s]
# Downloading data:  53% 120M/224M [00:01<00:01, 82.8MB/s]
# Downloading data:  57% 129M/224M [00:01<00:01, 83.7MB/s]
# Downloading data:  61% 137M/224M [00:01<00:01, 84.4MB/s]
# Downloading data:  65% 147M/224M [00:01<00:00, 87.5MB/s]
# Downloading data:  69% 156M/224M [00:01<00:00, 88.4MB/s]
# Downloading data:  74% 165M/224M [00:01<00:00, 90.6MB/s]
# Downloading data:  78% 175M/224M [00:02<00:00, 91.7MB/s]
# Downloading data:  82% 184M/224M [00:02<00:00, 92.1MB/s]
# Downloading data:  86% 193M/224M [00:02<00:00, 91.0MB/s]
# Downloading data:  90% 203M/224M [00:02<00:00, 92.0MB/s]
# Downloading data:  94% 212M/224M [00:02<00:00, 90.4MB/s]
# Downloading data: 100% 224M/224M [00:02<00:00, 86.6MB/s]
#
# Downloading data:   0% 0.00/227M [00:00<?, ?B/s]
# Downloading data:   2% 5.49M/227M [00:00<00:04, 54.9MB/s]
# Downloading data:   7% 14.8M/227M [00:00<00:02, 77.7MB/s]
# Downloading data:  10% 23.1M/227M [00:00<00:02, 79.9MB/s]
# Downloading data:  14% 32.4M/227M [00:00<00:02, 85.2MB/s]
# Downloading data:  18% 41.0M/227M [00:00<00:02, 71.3MB/s]
# Downloading data:  22% 49.5M/227M [00:00<00:02, 75.6MB/s]
# Downloading data:  26% 59.0M/227M [00:00<00:02, 81.3MB/s]
# Downloading data:  30% 67.9M/227M [00:00<00:01, 83.7MB/s]
# Downloading data:  34% 76.5M/227M [00:00<00:01, 83.6MB/s]
# Downloading data:  37% 85.0M/227M [00:01<00:01, 84.1MB/s]
# Downloading data:  41% 93.9M/227M [00:01<00:01, 85.5MB/s]
# Downloading data:  45% 102M/227M [00:01<00:01, 82.8MB/s]
# Downloading data:  49% 112M/227M [00:01<00:01, 86.9MB/s]
# Downloading data:  53% 121M/227M [00:01<00:01, 87.3MB/s]
# Downloading data:  57% 130M/227M [00:01<00:01, 87.7MB/s]
# Downloading data:  61% 139M/227M [00:01<00:01, 86.9MB/s]
# Downloading data:  65% 147M/227M [00:01<00:00, 87.1MB/s]
# Downloading data:  69% 156M/227M [00:01<00:00, 85.7MB/s]
# Downloading data:  73% 165M/227M [00:01<00:00, 87.8MB/s]
# Downloading data:  77% 175M/227M [00:02<00:00, 88.8MB/s]
# Downloading data:  81% 183M/227M [00:02<00:00, 86.4MB/s]
# Downloading data:  84% 192M/227M [00:02<00:00, 84.7MB/s]
# Downloading data:  88% 201M/227M [00:02<00:00, 85.9MB/s]
# Downloading data:  92% 210M/227M [00:02<00:00, 84.3MB/s]
# Downloading data: 100% 227M/227M [00:02<00:00, 84.9MB/s]
#
# Downloading data:   0% 0.00/232M [00:00<?, ?B/s]
# Downloading data:   2% 5.64M/232M [00:00<00:04, 56.4MB/s]
# Downloading data:   6% 15.0M/232M [00:00<00:02, 78.4MB/s]
# Downloading data:  10% 24.2M/232M [00:00<00:02, 84.4MB/s]
# Downloading data:  15% 33.9M/232M [00:00<00:02, 89.6MB/s]
# Downloading data:  19% 43.4M/232M [00:00<00:02, 91.4MB/s]
# Downloading data:  23% 52.5M/232M [00:00<00:02, 77.1MB/s]
# Downloading data:  26% 60.9M/232M [00:00<00:02, 79.2MB/s]
# Downloading data:  30% 69.8M/232M [00:00<00:01, 82.0MB/s]
# Downloading data:  34% 78.4M/232M [00:00<00:01, 83.0MB/s]
# Downloading data:  37% 86.8M/232M [00:01<00:01, 82.1MB/s]
# Downloading data:  41% 95.6M/232M [00:01<00:01, 83.9MB/s]
# Downloading data:  45% 105M/232M [00:01<00:01, 86.1MB/s]
# Downloading data:  49% 113M/232M [00:01<00:01, 71.9MB/s]
# Downloading data:  52% 121M/232M [00:01<00:01, 68.2MB/s]
# Downloading data:  55% 128M/232M [00:01<00:01, 64.9MB/s]
# Downloading data:  58% 135M/232M [00:01<00:01, 62.7MB/s]
# Downloading data:  61% 141M/232M [00:01<00:01, 60.4MB/s]
# Downloading data:  64% 147M/232M [00:02<00:01, 59.4MB/s]
# Downloading data:  66% 153M/232M [00:02<00:01, 56.8MB/s]
# Downloading data:  69% 159M/232M [00:02<00:01, 56.3MB/s]
# Downloading data:  71% 165M/232M [00:02<00:01, 56.0MB/s]
# Downloading data:  74% 170M/232M [00:02<00:01, 55.8MB/s]
# Downloading data:  76% 176M/232M [00:02<00:00, 56.2MB/s]
# Downloading data:  78% 182M/232M [00:02<00:00, 56.0MB/s]
# Downloading data:  81% 187M/232M [00:02<00:00, 54.0MB/s]
# Downloading data:  83% 193M/232M [00:02<00:00, 54.9MB/s]
# Downloading data:  86% 199M/232M [00:02<00:00, 56.2MB/s]
# Downloading data:  88% 205M/232M [00:03<00:00, 57.1MB/s]
# Downloading data:  91% 211M/232M [00:03<00:00, 56.3MB/s]
# Downloading data:  94% 217M/232M [00:03<00:00, 57.2MB/s]
# Downloading data:  96% 222M/232M [00:03<00:00, 57.3MB/s]
# Downloading data: 100% 232M/232M [00:03<00:00, 65.7MB/s]
#
# Downloading data:   0% 0.00/230M [00:00<?, ?B/s]
# Downloading data:   2% 4.07M/230M [00:00<00:05, 40.6MB/s]
# Downloading data:   4% 9.25M/230M [00:00<00:04, 47.2MB/s]
# Downloading data:   6% 14.5M/230M [00:00<00:04, 49.6MB/s]
# Downloading data:   9% 20.1M/230M [00:00<00:04, 52.2MB/s]
# Downloading data:  11% 25.6M/230M [00:00<00:03, 53.0MB/s]
# Downloading data:  14% 31.2M/230M [00:00<00:03, 54.3MB/s]
# Downloading data:  16% 36.8M/230M [00:00<00:03, 54.7MB/s]
# Downloading data:  18% 42.3M/230M [00:00<00:03, 54.7MB/s]
# Downloading data:  22% 49.6M/230M [00:00<00:02, 60.6MB/s]
# Downloading data:  26% 58.7M/230M [00:01<00:02, 69.9MB/s]
# Downloading data:  29% 67.0M/230M [00:01<00:02, 73.9MB/s]
# Downloading data:  32% 74.4M/230M [00:01<00:02, 68.5MB/s]
# Downloading data:  36% 83.3M/230M [00:01<00:01, 74.5MB/s]
# Downloading data:  40% 91.7M/230M [00:01<00:01, 77.1MB/s]
# Downloading data:  44% 101M/230M [00:01<00:01, 81.1MB/s]
# Downloading data:  47% 109M/230M [00:01<00:01, 82.4MB/s]
# Downloading data:  51% 118M/230M [00:01<00:01, 83.2MB/s]
# Downloading data:  55% 127M/230M [00:01<00:01, 84.7MB/s]
# Downloading data:  59% 135M/230M [00:01<00:01, 80.6MB/s]
# Downloading data:  63% 145M/230M [00:02<00:01, 84.4MB/s]
# Downloading data:  67% 154M/230M [00:02<00:00, 86.3MB/s]
# Downloading data:  71% 162M/230M [00:02<00:00, 87.0MB/s]
# Downloading data:  75% 172M/230M [00:02<00:00, 88.1MB/s]
# Downloading data:  78% 181M/230M [00:02<00:00, 88.7MB/s]
# Downloading data:  82% 190M/230M [00:02<00:00, 89.6MB/s]
# Downloading data:  86% 199M/230M [00:02<00:00, 90.7MB/s]
# Downloading data:  91% 209M/230M [00:02<00:00, 92.8MB/s]
# Downloading data:  95% 218M/230M [00:02<00:00, 93.4MB/s]
# Downloading data: 100% 230M/230M [00:02<00:00, 77.4MB/s]
#
# Downloading data:   0% 0.00/233M [00:00<?, ?B/s]
# Downloading data:   2% 5.42M/233M [00:00<00:04, 54.2MB/s]
# Downloading data:   6% 13.5M/233M [00:00<00:03, 69.6MB/s]
# Downloading data:  10% 22.9M/233M [00:00<00:02, 80.5MB/s]
# Downloading data:  13% 30.9M/233M [00:00<00:02, 71.2MB/s]
# Downloading data:  17% 40.2M/233M [00:00<00:02, 78.3MB/s]
# Downloading data:  21% 48.7M/233M [00:00<00:02, 80.5MB/s]
# Downloading data:  25% 57.3M/233M [00:00<00:02, 82.1MB/s]
# Downloading data:  28% 66.0M/233M [00:00<00:01, 83.8MB/s]
# Downloading data:  32% 74.9M/233M [00:00<00:01, 85.4MB/s]
# Downloading data:  36% 84.0M/233M [00:01<00:01, 86.9MB/s]
# Downloading data:  40% 92.7M/233M [00:01<00:01, 86.4MB/s]
# Downloading data:  43% 101M/233M [00:01<00:01, 86.5MB/s]
# Downloading data:  47% 111M/233M [00:01<00:01, 88.6MB/s]
# Downloading data:  51% 120M/233M [00:01<00:01, 89.4MB/s]
# Downloading data:  55% 129M/233M [00:01<00:01, 90.4MB/s]
# Downloading data:  59% 138M/233M [00:01<00:01, 89.9MB/s]
# Downloading data:  63% 147M/233M [00:01<00:00, 90.6MB/s]
# Downloading data:  67% 157M/233M [00:01<00:00, 92.3MB/s]
# Downloading data:  71% 166M/233M [00:01<00:00, 91.1MB/s]
# Downloading data:  75% 175M/233M [00:02<00:00, 91.2MB/s]
# Downloading data:  79% 186M/233M [00:02<00:00, 94.1MB/s]
# Downloading data:  84% 195M/233M [00:02<00:00, 92.6MB/s]
# Downloading data:  88% 205M/233M [00:02<00:00, 94.0MB/s]
# Downloading data:  92% 214M/233M [00:02<00:00, 88.7MB/s]
# Downloading data:  96% 223M/233M [00:02<00:00, 83.2MB/s]
# Downloading data: 100% 233M/233M [00:02<00:00, 86.3MB/s]
#
# Downloading data: 100% 4.04M/4.04M [00:00<00:00, 54.4MB/s]
# Downloading data files:  25% 1/4 [02:08<06:25, 128.61s/it]
# Downloading data: 100% 1.26k/1.26k [00:00<00:00, 9.13MB/s]
# Downloading data files:  50% 2/4 [02:08<01:46, 53.18s/it]
# Downloading data:   0% 0.00/4.97M [00:00<?, ?B/s]
# Downloading data: 100% 4.97M/4.97M [00:00<00:00, 30.9MB/s]
# Downloading data files:  75% 3/4 [02:09<00:29, 29.13s/it]
# Downloading data: 100% 659k/659k [00:00<00:00, 15.1MB/s]
# Downloading data files: 100% 4/4 [02:09<00:00, 32.48s/it]
# Extracting data files: 100% 4/4 [00:00<00:00, 835.06it/s]
# Generating train split: 100% 79641/79641 [00:58<00:00, 1361.79 examples/s]
# Generating test split: 100% 15972/15972 [00:31<00:00, 505.62 examples/s]
# Generating validation split: 100% 10861/10861 [00:20<00:00, 518.89 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2096: FutureWarning: 'ignore_verifications' was deprecated in favor of 'verification_mode' in version 2.9.1 and will be removed in 3.0.0.
# You can remove this warning by passing 'verification_mode=no_checks' instead.
#   warnings.warn(
# Filter: 100% 79641/79641 [00:16<00:00, 4697.41 examples/s]
# Filter: 100% 10861/10861 [00:02<00:00, 5107.34 examples/s]
# Map: 100% 79414/79414 [01:50<00:00, 718.78 examples/s]
# Map: 100% 10831/10831 [00:14<00:00, 758.79 examples/s]
# Computing stats..: 100% 4964/4964 [03:29<00:00, 23.74it/s]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 144MB/s]
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ResNetModel                                   --
# ├─ResNet: 1-1                                 --
# │    └─Conv2d: 2-1                            (9,408)
# │    └─BatchNorm2d: 2-2                       (128)
# │    └─ReLU: 2-3                              --
# │    └─MaxPool2d: 2-4                         --
# │    └─Sequential: 2-5                        --
# │    │    └─BasicBlock: 3-1                   (73,984)
# │    │    └─BasicBlock: 3-2                   (73,984)
# │    └─Sequential: 2-6                        --
# │    │    └─BasicBlock: 3-3                   (230,144)
# │    │    └─BasicBlock: 3-4                   (295,424)
# │    └─Sequential: 2-7                        --
# │    │    └─BasicBlock: 3-5                   (919,040)
# │    │    └─BasicBlock: 3-6                   (1,180,672)
# │    └─Sequential: 2-8                        --
# │    │    └─BasicBlock: 3-7                   (3,673,088)
# │    │    └─BasicBlock: 3-8                   4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 --
# │    └─Linear: 2-10                           2,565
# ======================================================================
# Total params: 11,179,077
# Trainable params: 4,723,205
# Non-trainable params: 6,455,872
# ======================================================================
# macro
# micro
# Epoch 0:
# Training...: 100% 4963/4963 [03:59<00:00, 20.68it/s, loss=0.434, acc=0.437]
# Validation...: 100% 676/676 [00:31<00:00, 21.33it/s, loss=0.39, acc=0.492]
# train_loss: 0.4341 | val_loss: 0.3905 | train_acc: 0.4369 | val_acc: 0.4923 | train_macro_f1: 0.4211 | train_macro_precision: 0.6939 | train_macro_recall: 0.3611 | train_micro_f1: 0.5596 | train_micro_precision: 0.7065 | train_micro_recall: 0.4633 | val_macro_f1: 0.5262 | val_macro_precision: 0.7363 | val_macro_recall: 0.4451 | val_micro_f1: 0.6266 | val_micro_precision: 0.7559 | val_micro_recall: 0.5351
#
# Epoch 1:
# Training...: 100% 4963/4963 [03:49<00:00, 21.58it/s, loss=0.392, acc=0.485]
# Validation...: 100% 676/676 [00:31<00:00, 21.69it/s, loss=0.369, acc=0.518]
# train_loss: 0.3925 | val_loss: 0.3686 | train_acc: 0.4854 | val_acc: 0.5182 | train_macro_f1: 0.5258 | train_macro_precision: 0.7285 | train_macro_recall: 0.4495 | train_micro_f1: 0.6234 | train_micro_precision: 0.7425 | train_micro_recall: 0.5371 | val_macro_f1: 0.5879 | val_macro_precision: 0.7241 | val_macro_recall: 0.5213 | val_micro_f1: 0.6646 | val_micro_precision: 0.7464 | val_micro_recall: 0.5990
#
# Epoch 2:
# Training...: 100% 4963/4963 [03:51<00:00, 21.47it/s, loss=0.372, acc=0.51]
# Validation...: 100% 676/676 [00:32<00:00, 20.63it/s, loss=0.356, acc=0.531]
# train_loss: 0.3721 | val_loss: 0.3562 | train_acc: 0.5096 | val_acc: 0.5312 | train_macro_f1: 0.5678 | train_macro_precision: 0.7442 | train_macro_recall: 0.4890 | train_micro_f1: 0.6503 | train_micro_precision: 0.7580 | train_micro_recall: 0.5694 | val_macro_f1: 0.6049 | val_macro_precision: 0.7481 | val_macro_recall: 0.5496 | val_micro_f1: 0.6829 | val_micro_precision: 0.7435 | val_micro_recall: 0.6314
#
# Epoch 3:
# Training...: 100% 4963/4963 [03:54<00:00, 21.14it/s, loss=0.356, acc=0.53]
# Validation...: 100% 676/676 [00:32<00:00, 21.08it/s, loss=0.345, acc=0.551]
# train_loss: 0.3557 | val_loss: 0.3451 | train_acc: 0.5296 | val_acc: 0.5510 | train_macro_f1: 0.5984 | train_macro_precision: 0.7558 | train_macro_recall: 0.5205 | train_micro_f1: 0.6717 | train_micro_precision: 0.7692 | train_micro_recall: 0.5960 | val_macro_f1: 0.6340 | val_macro_precision: 0.7439 | val_macro_recall: 0.5701 | val_micro_f1: 0.6954 | val_micro_precision: 0.7621 | val_micro_recall: 0.6394
#
# Epoch 4:
# Training...: 100% 4963/4963 [03:56<00:00, 20.97it/s, loss=0.341, acc=0.546]
# Validation...: 100% 676/676 [00:32<00:00, 20.58it/s, loss=0.336, acc=0.564]
# train_loss: 0.3415 | val_loss: 0.3364 | train_acc: 0.5461 | val_acc: 0.5639 | train_macro_f1: 0.6224 | train_macro_precision: 0.7675 | train_macro_recall: 0.5457 | train_micro_f1: 0.6882 | train_micro_precision: 0.7777 | train_micro_recall: 0.6171 | val_macro_f1: 0.6322 | val_macro_precision: 0.7936 | val_macro_recall: 0.5518 | val_micro_f1: 0.6996 | val_micro_precision: 0.7938 | val_micro_recall: 0.6254
#
# Epoch 5:
# Training...: 100% 4963/4963 [03:51<00:00, 21.40it/s, loss=0.328, acc=0.562]
# Validation...: 100% 676/676 [00:31<00:00, 21.36it/s, loss=0.333, acc=0.568]
# train_loss: 0.3281 | val_loss: 0.3327 | train_acc: 0.5620 | val_acc: 0.5679 | train_macro_f1: 0.6449 | train_macro_precision: 0.7756 | train_macro_recall: 0.5705 | train_micro_f1: 0.7059 | train_micro_precision: 0.7887 | train_micro_recall: 0.6387 | val_macro_f1: 0.6511 | val_macro_precision: 0.7610 | val_macro_recall: 0.5892 | val_micro_f1: 0.7101 | val_micro_precision: 0.7694 | val_micro_recall: 0.6594
#
# Epoch 6:
# Training...: 100% 4963/4963 [03:48<00:00, 21.69it/s, loss=0.315, acc=0.576]
# Validation...: 100% 676/676 [00:31<00:00, 21.48it/s, loss=0.326, acc=0.58]
# train_loss: 0.3149 | val_loss: 0.3258 | train_acc: 0.5760 | val_acc: 0.5799 | train_macro_f1: 0.6647 | train_macro_precision: 0.7866 | train_macro_recall: 0.5920 | train_micro_f1: 0.7199 | train_micro_precision: 0.7970 | train_micro_recall: 0.6563 | val_macro_f1: 0.6629 | val_macro_precision: 0.7686 | val_macro_recall: 0.6014 | val_micro_f1: 0.7203 | val_micro_precision: 0.7796 | val_micro_recall: 0.6694
#
# Epoch 7:
# Training...: 100% 4963/4963 [03:50<00:00, 21.49it/s, loss=0.303, acc=0.589]
# Validation...: 100% 676/676 [00:33<00:00, 20.40it/s, loss=0.32, acc=0.587]
# train_loss: 0.3029 | val_loss: 0.3199 | train_acc: 0.5889 | val_acc: 0.5870 | train_macro_f1: 0.6825 | train_macro_precision: 0.7926 | train_macro_recall: 0.6129 | train_micro_f1: 0.7335 | train_micro_precision: 0.8048 | train_micro_recall: 0.6738 | val_macro_f1: 0.6781 | val_macro_precision: 0.7587 | val_macro_recall: 0.6249 | val_micro_f1: 0.7265 | val_micro_precision: 0.7757 | val_micro_recall: 0.6831
#
# Epoch 8:
# Training...: 100% 4963/4963 [03:50<00:00, 21.53it/s, loss=0.29, acc=0.601]
# Validation...: 100% 676/676 [00:31<00:00, 21.38it/s, loss=0.324, acc=0.584]
# train_loss: 0.2904 | val_loss: 0.3237 | train_acc: 0.6015 | val_acc: 0.5837 | train_macro_f1: 0.6991 | train_macro_precision: 0.8016 | train_macro_recall: 0.6323 | train_micro_f1: 0.7471 | train_micro_precision: 0.8131 | train_micro_recall: 0.6910 | val_macro_f1: 0.6621 | val_macro_precision: 0.7724 | val_macro_recall: 0.5963 | val_micro_f1: 0.7158 | val_micro_precision: 0.7915 | val_micro_recall: 0.6533
#
# Epoch 9:
# Training...: 100% 4963/4963 [03:51<00:00, 21.42it/s, loss=0.278, acc=0.616]
# Validation...: 100% 676/676 [00:31<00:00, 21.66it/s, loss=0.316, acc=0.595]
# train_loss: 0.2776 | val_loss: 0.3160 | train_acc: 0.6165 | val_acc: 0.5954 | train_macro_f1: 0.7170 | train_macro_precision: 0.8100 | train_macro_recall: 0.6536 | train_micro_f1: 0.7610 | train_micro_precision: 0.8215 | train_micro_recall: 0.7089 | val_macro_f1: 0.6833 | val_macro_precision: 0.7707 | val_macro_recall: 0.6269 | val_micro_f1: 0.7322 | val_micro_precision: 0.7870 | val_micro_recall: 0.6846
#
# Epoch 10:
# Training...: 100% 4963/4963 [03:51<00:00, 21.42it/s, loss=0.264, acc=0.631]
# Validation...: 100% 676/676 [00:31<00:00, 21.21it/s, loss=0.319, acc=0.607]
# train_loss: 0.2641 | val_loss: 0.3185 | train_acc: 0.6306 | val_acc: 0.6074 | train_macro_f1: 0.7352 | train_macro_precision: 0.8188 | train_macro_recall: 0.6760 | train_micro_f1: 0.7760 | train_micro_precision: 0.8303 | train_micro_recall: 0.7283 | val_macro_f1: 0.6912 | val_macro_precision: 0.7790 | val_macro_recall: 0.6302 | val_micro_f1: 0.7347 | val_micro_precision: 0.7974 | val_micro_recall: 0.6812
#
# Epoch 11:
# Training...: 100% 4963/4963 [03:45<00:00, 22.03it/s, loss=0.253, acc=0.643]
# Validation...: 100% 676/676 [00:30<00:00, 21.99it/s, loss=0.32, acc=0.614]
# train_loss: 0.2525 | val_loss: 0.3203 | train_acc: 0.6431 | val_acc: 0.6145 | train_macro_f1: 0.7509 | train_macro_precision: 0.8273 | train_macro_recall: 0.6952 | train_micro_f1: 0.7880 | train_micro_precision: 0.8375 | train_micro_recall: 0.7441 | val_macro_f1: 0.7044 | val_macro_precision: 0.7578 | val_macro_recall: 0.6602 | val_micro_f1: 0.7414 | val_micro_precision: 0.7873 | val_micro_recall: 0.7006
#
# Epoch 12:
# Training...:  26% 1312/4963 [00:59<02:39, 22.87it/s, loss=0.238, acc=0.659]
